# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content

soup = BeautifulSoup(c,"html.parser")

all = soup.find_all("div",{"class": "propertyRow"})

all[0].find("h4",{"class": "propPrice"}).text.replace("\n","").replace(" ","")

page_nr=soup.find_all("a",{"class":"Page"})[-1].text

# %%
l = []
base_url="http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s="
for page in range(0,int(page_nr)*10,10):
    r = requests.get(base_url+str(page)+".html",headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    c = r.content
    soup = BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class":"propAddressCollapse"})[0].text
        try:
            d["Locality"]=item.find_all("span",{"class":"propAddressCollapse"})[1].text
        except:
            d["Locality"]=None
        d["Price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
        try:
            d["Beds"]=item.find("span",{"class":"infoBed"}).find("b").text
        except:
            d["Beds"]=None
        try:
            d["Area"]=item.find("span",{"class":"infoSqFt"}).find("b").text
        except:
            d["Area"]=None
        try:
            d["Full Baths"]=item.find("span",{"class":"infoValueFullBath"}).find("b").text
        except:
             d["Full Baths"]=None
        try:
            d["Half Baths"]=item.find("span",{"class":"infoValueHalfBath"}).find("b").text
        except:
            d["Half Baths"]=None
        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text    
        l.append(d)

# %%
l
# Out:
# [{'Address': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$452,900',
#   'Beds': '4',
#   'Area': None,
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Lot Size': '0.21 Acres'},
#  {'Address': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900',
#   'Beds': '5',
#   'Area': '3,154',
#   'Full Baths': '3',
#   'Half Baths': None},
#  {'Address': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$389,900',
#   'Beds': '4',
#   'Area': '3,076',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$254,000',
#   'Beds': '3',
#   'Area': '1,172',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': "1302 Veteran's Drive",
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$252,900',
#   'Beds': '4',
#   'Area': '1,932',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '0.27 Acres'},
#  {'Address': '1021 Cypress Cir',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$210,000',
#   'Beds': '4',
#   'Area': '1,676',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '913 Madison Dr',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$209,000',
#   'Beds': '3',
#   'Area': '1,344',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '1344 Teton Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$199,900',
#   'Beds': '3',
#   'Area': '1,920',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '4 Minnies Lane',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$196,900',
#   'Beds': '3',
#   'Area': '1,664',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '2.02 Acres'},
#  {'Address': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$452,900',
#   'Beds': '4',
#   'Area': None,
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Lot Size': '0.21 Acres'},
#  {'Address': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900',
#   'Beds': '5',
#   'Area': '3,154',
#   'Full Baths': '3',
#   'Half Baths': None},
#  {'Address': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$389,900',
#   'Beds': '4',
#   'Area': '3,076',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$254,000',
#   'Beds': '3',
#   'Area': '1,172',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': "1302 Veteran's Drive",
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$252,900',
#   'Beds': '4',
#   'Area': '1,932',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '0.27 Acres'},
#  {'Address': '1021 Cypress Cir',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$210,000',
#   'Beds': '4',
#   'Area': '1,676',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '913 Madison Dr',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$209,000',
#   'Beds': '3',
#   'Area': '1,344',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '1344 Teton Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$199,900',
#   'Beds': '3',
#   'Area': '1,920',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '4 Minnies Lane',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$196,900',
#   'Beds': '3',
#   'Area': '1,664',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '2.02 Acres'},
#  {'Address': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$452,900',
#   'Beds': '4',
#   'Area': None,
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Lot Size': '0.21 Acres'},
#  {'Address': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900',
#   'Beds': '5',
#   'Area': '3,154',
#   'Full Baths': '3',
#   'Half Baths': None},
#  {'Address': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$389,900',
#   'Beds': '4',
#   'Area': '3,076',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$254,000',
#   'Beds': '3',
#   'Area': '1,172',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': "1302 Veteran's Drive",
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$252,900',
#   'Beds': '4',
#   'Area': '1,932',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '0.27 Acres'},
#  {'Address': '1021 Cypress Cir',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$210,000',
#   'Beds': '4',
#   'Area': '1,676',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '913 Madison Dr',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$209,000',
#   'Beds': '3',
#   'Area': '1,344',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '1344 Teton Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$199,900',
#   'Beds': '3',
#   'Area': '1,920',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '4 Minnies Lane',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$196,900',
#   'Beds': '3',
#   'Area': '1,664',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '2.02 Acres'}]

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#                   Address                Locality     Price  Beds   Area  \
# 0               0 Gateway  Rock Springs, WY 82901  $725,000  None   None
# 1   1003 Winchester Blvd.  Rock Springs, WY 82901  $452,900     4   None
# 2           600 Talladega  Rock Springs, WY 82901  $396,900     5  3,154
# 3      3239 Spearhead Way  Rock Springs, WY 82901  $389,900     4  3,076
# 4      522 Emerald Street  Rock Springs, WY 82901  $254,000     3  1,172
# 5    1302 Veteran's Drive  Rock Springs, WY 82901  $252,900     4  1,932
# 6        1021 Cypress Cir  Rock Springs, WY 82901  $210,000     4  1,676
# 7          913 Madison Dr  Rock Springs, WY 82901  $209,000     3  1,344
# 8       1344 Teton Street  Rock Springs, WY 82901  $199,900     3  1,920
# 9          4 Minnies Lane  Rock Springs, WY 82901  $196,900     3  1,664
# 10              0 Gateway  Rock Springs, WY 82901  $725,000  None   None
# 11  1003 Winchester Blvd.  Rock Springs, WY 82901  $452,900     4   None
# 12          600 Talladega  Rock Springs, WY 82901  $396,900     5  3,154
# 13     3239 Spearhead Way  Rock Springs, WY 82901  $389,900     4  3,076
# 14     522 Emerald Street  Rock Springs, WY 82901  $254,000     3  1,172
# 15   1302 Veteran's Drive  Rock Springs, WY 82901  $252,900     4  1,932
# 16       1021 Cypress Cir  Rock Springs, WY 82901  $210,000     4  1,676
# 17         913 Madison Dr  Rock Springs, WY 82901  $209,000     3  1,344
# 18      1344 Teton Street  Rock Springs, WY 82901  $199,900     3  1,920
# 19         4 Minnies Lane  Rock Springs, WY 82901  $196,900     3  1,664
# 20              0 Gateway  Rock Springs, WY 82901  $725,000  None   None
# 21  1003 Winchester Blvd.  Rock Springs, WY 82901  $452,900     4   None
# 22          600 Talladega  Rock Springs, WY 82901  $396,900     5  3,154
# 23     3239 Spearhead Way  Rock Springs, WY 82901  $389,900     4  3,076
# 24     522 Emerald Street  Rock Springs, WY 82901  $254,000     3  1,172
# 25   1302 Veteran's Drive  Rock Springs, WY 82901  $252,900     4  1,932
# 26       1021 Cypress Cir  Rock Springs, WY 82901  $210,000     4  1,676
# 27         913 Madison Dr  Rock Springs, WY 82901  $209,000     3  1,344
# 28      1344 Teton Street  Rock Springs, WY 82901  $199,900     3  1,920
# 29         4 Minnies Lane  Rock Springs, WY 82901  $196,900     3  1,664
#
#    Full Baths Half Baths          Lot Size
# 0        None       None               NaN
# 1           4       None        0.21 Acres
# 2           3       None               NaN
# 3           3          1  Under 1/2 Acre,
# 4           3       None  Under 1/2 Acre,
# 5           2       None        0.27 Acres
# 6           3       None  Under 1/2 Acre,
# 7           2       None  Under 1/2 Acre,
# 8           2       None  Under 1/2 Acre,
# 9           2       None        2.02 Acres
# 10       None       None               NaN
# 11          4       None        0.21 Acres
# 12          3       None               NaN
# 13          3          1  Under 1/2 Acre,
# 14          3       None  Under 1/2 Acre,
# 15          2       None        0.27 Acres
# 16          3       None  Under 1/2 Acre,
# 17          2       None  Under 1/2 Acre,
# 18          2       None  Under 1/2 Acre,
# 19          2       None        2.02 Acres
# 20       None       None               NaN
# 21          4       None        0.21 Acres
# 22          3       None               NaN
# 23          3          1  Under 1/2 Acre,
# 24          3       None  Under 1/2 Acre,
# 25          2       None        0.27 Acres
# 26          3       None  Under 1/2 Acre,
# 27          2       None  Under 1/2 Acre,
# 28          2       None  Under 1/2 Acre,
# 29          2       None        2.02 Acres

# %%
df.to_csv("Output.csv")
